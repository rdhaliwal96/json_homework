# %%
# After examining the plots it is clear to see that the temperature does increase the closer you get to the equator.
## my last graph looks like a world map!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
from citipy import citipy
from datetime import datetime
from random import uniform


# Create a df to lat, lon 
column_names = ["City", "Country"]
cities_df = pd.DataFrame(columns=column_names)

api_key = "d6810bdaefe467cd40907ae8b7ed7c10"

# %% [markdown]
# ## Generate Cities List

# %%
# Randomly generate a list of 1750 cities. Use 50 to test for duplicates.
for x in range(1750):
    lat, lng = np.random.uniform(low=-90.000, high=90.000), np.random.uniform(low=-180.000, high=180.000)
    city = citipy.nearest_city(lat, lng)
    cities_df = cities_df.append({"City": city.city_name,"Country": city.country_code,}, ignore_index=True)

#Remove duplicate cities
cities_df = cities_df.drop_duplicates(subset='City').reset_index()
cities_df.count()
# Out:
# index      693
# City       693
# Country    693
# dtype: int64

# %%
#Create a df to add all the data from the API calls.
column_names = ["City", "Country","Temperature (F)",
                "Latitude","Longitude","Humidity (%)",
                "Cloudiness (%)", "Wind Speed (mph)"]
clean_cities_df = pd.DataFrame(columns=column_names)

# Loop through the list of cities and add the data to the df.
url = "http://api.openweathermap.org/data/2.5/weather?"

row_count = 1

print("Beginning Data Retrieval")
for index, row in cities_df.iterrows():
    target_city = row["City"]
    target_url = url + "appid=" + api_key + "&units=IMPERIAL" + "&q=" + target_city.replace(" ","+")
    city_data = requests.get(target_url).json()
    if city_data["cod"] == "404":
        print("City not found, skipping...")

    else:
        clean_cities_df.set_value(index, "City", city_data["name"])
        clean_cities_df.set_value(index, "Country", city_data["sys"]["country"])
        clean_cities_df.set_value(index, "Temperature (F)", city_data["main"]["temp"])
        clean_cities_df.set_value(index, "Latitude", city_data["coord"]["lat"])
        clean_cities_df.set_value(index, "Longitude", city_data["coord"]["lon"])
        clean_cities_df.set_value(index, "Humidity (%)", city_data["main"]["humidity"])
        clean_cities_df.set_value(index, "Cloudiness (%)", city_data["clouds"]["all"])
        clean_cities_df.set_value(index, "Wind Speed (mph)", city_data["wind"]["speed"])
        
        print("------------------------")
        print("Proceesing: City # " , row_count, ' | ' , city_data["name"], city_data["sys"]["country"])
        print(target_url)
        row_count += 1
# Out:
# Beginning Data Retrieval
# C:\Users\raman\Anaconda3\envs\PythonData\lib\site-packages\ipykernel\__main__.py:21: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\raman\Anaconda3\envs\PythonData\lib\site-packages\ipykernel\__main__.py:22: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\raman\Anaconda3\envs\PythonData\lib\site-packages\ipykernel\__main__.py:23: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\raman\Anaconda3\envs\PythonData\lib\site-packages\ipykernel\__main__.py:24: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\raman\Anaconda3\envs\PythonData\lib\site-packages\ipykernel\__main__.py:25: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\raman\Anaconda3\envs\PythonData\lib\site-packages\ipykernel\__main__.py:26: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\raman\Anaconda3\envs\PythonData\lib\site-packages\ipykernel\__main__.py:27: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\raman\Anaconda3\envs\PythonData\lib\site-packages\ipykernel\__main__.py:28: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# ------------------------
# Proceesing: City #  1  |  Punta Arenas CL
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=punta+arenas
# ------------------------
# Proceesing: City #  2  |  Havoysund NO
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=havoysund
# ------------------------
# Proceesing: City #  3  |  Roald NO
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=roald
# ------------------------
# Proceesing: City #  4  |  Batsfjord NO
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=batsfjord
# ------------------------
# Proceesing: City #  5  |  Hofn IS
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=hofn
# ------------------------
# Proceesing: City #  6  |  Alofi NU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=alofi
# ------------------------
# Proceesing: City #  7  |  Marau BR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=marau
# City not found, skipping...
# ------------------------
# Proceesing: City #  8  |  Busselton AU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=busselton
# ------------------------
# Proceesing: City #  9  |  Filadelfia PY
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=filadelfia
# ------------------------
# Proceesing: City #  10  |  Qaanaaq GL
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=qaanaaq
# ------------------------
# Proceesing: City #  11  |  Weatherford US
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=weatherford
# ------------------------
# Proceesing: City #  12  |  Kavaratti IN
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=kavaratti
# ------------------------
# Proceesing: City #  13  |  Torbay CA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=torbay
# ------------------------
# Proceesing: City #  14  |  Segamat MY
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=segamat
# ------------------------
# Proceesing: City #  15  |  Saskylakh RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=saskylakh
# ------------------------
# Proceesing: City #  16  |  Jamestown AU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=jamestown
# ------------------------
# Proceesing: City #  17  |  Krasnyy Chikoy RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=krasnyy+chikoy
# ------------------------
# Proceesing: City #  18  |  Saldanha PT
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=saldanha
# ------------------------
# Proceesing: City #  19  |  Airai TL
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=airai
# ------------------------
# Proceesing: City #  20  |  Yulara AU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=yulara
# ------------------------
# Proceesing: City #  21  |  Ushuaia AR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=ushuaia
# ------------------------
# Proceesing: City #  22  |  Praia BR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=praia
# ------------------------
# Proceesing: City #  23  |  Severo-Yeniseyskiy RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=severo-yeniseyskiy
# ------------------------
# Proceesing: City #  24  |  New Norfolk AU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=new+norfolk
# ------------------------
# Proceesing: City #  25  |  Sao Domingos BR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=sao+domingos
# ------------------------
# Proceesing: City #  26  |  Goderich CA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=goderich
# ------------------------
# Proceesing: City #  27  |  Livingston US
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=livingston
# ------------------------
# Proceesing: City #  28  |  Cockburn Town TC
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=cockburn+town
# City not found, skipping...
# ------------------------
# Proceesing: City #  29  |  Verkhnevilyuysk RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=verkhnevilyuysk
# ------------------------
# Proceesing: City #  30  |  Zaykovo RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=zaykovo
# ------------------------
# Proceesing: City #  31  |  Albany US
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=albany
# City not found, skipping...
# ------------------------
# Proceesing: City #  32  |  Tasiilaq GL
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=tasiilaq
# ------------------------
# Proceesing: City #  33  |  Pevek RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=pevek
# ------------------------
# Proceesing: City #  34  |  Avarua CK
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=avarua
# ------------------------
# Proceesing: City #  35  |  Port Alfred ZA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=port+alfred
# ------------------------
# Proceesing: City #  36  |  Hobart AU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=hobart
# ------------------------
# Proceesing: City #  37  |  Kapaa US
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=kapaa
# ------------------------
# Proceesing: City #  38  |  Norman Wells CA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=norman+wells
# ------------------------
# Proceesing: City #  39  |  Mar del Plata AR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=mar+del+plata
# ------------------------
# Proceesing: City #  40  |  Souillac FR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=souillac
# ------------------------
# Proceesing: City #  41  |  Victoria BN
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=victoria
# ------------------------
# Proceesing: City #  42  |  Bluff AU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=bluff
# ------------------------
# Proceesing: City #  43  |  Cape Town ZA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=cape+town
# ------------------------
# Proceesing: City #  44  |  Arraial do Cabo BR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=arraial+do+cabo
# ------------------------
# Proceesing: City #  45  |  Mataura NZ
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=mataura
# ------------------------
# Proceesing: City #  46  |  Atuona PF
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=atuona
# City not found, skipping...
# ------------------------
# Proceesing: City #  47  |  Puerto Ayora EC
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=puerto+ayora
# City not found, skipping...
# ------------------------
# Proceesing: City #  48  |  Provideniya RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=provideniya
# ------------------------
# Proceesing: City #  49  |  Bredasdorp ZA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=bredasdorp
# ------------------------
# Proceesing: City #  50  |  Ketchikan US
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=ketchikan
# ------------------------
# Proceesing: City #  51  |  Tiksi RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=tiksi
# City not found, skipping...
# ------------------------
# Proceesing: City #  52  |  Kawambwa ZM
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=kawambwa
# ------------------------
# Proceesing: City #  53  |  Santa Ana SV
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=santa+ana
# ------------------------
# Proceesing: City #  54  |  Rio Negro PE
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=rio+negro
# City not found, skipping...
# ------------------------
# Proceesing: City #  55  |  Aklavik CA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=aklavik
# City not found, skipping...
# ------------------------
# Proceesing: City #  56  |  Mehamn NO
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=mehamn
# ------------------------
# Proceesing: City #  57  |  Mahebourg MU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=mahebourg
# ------------------------
# Proceesing: City #  58  |  Yellowknife CA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=yellowknife
# ------------------------
# Proceesing: City #  59  |  Orchard Homes US
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=orchard+homes
# ------------------------
# Proceesing: City #  60  |  Nikolskoye RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=nikolskoye
# City not found, skipping...
# ------------------------
# Proceesing: City #  61  |  Aksu KZ
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=aksu
# City not found, skipping...
# ------------------------
# Proceesing: City #  62  |  Chuy UY
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=chuy
# ------------------------
# Proceesing: City #  63  |  Castro CL
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=castro
# ------------------------
# Proceesing: City #  64  |  Khatanga RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=khatanga
# ------------------------
# Proceesing: City #  65  |  Novaya Ladoga RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=novaya+ladoga
# ------------------------
# Proceesing: City #  66  |  Fortuna ES
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=fortuna
# ------------------------
# Proceesing: City #  67  |  Lebu ET
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=lebu
# ------------------------
# Proceesing: City #  68  |  Hithadhoo MV
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=hithadhoo
# City not found, skipping...
# ------------------------
# Proceesing: City #  69  |  Kajaani FI
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=kajaani
# ------------------------
# Proceesing: City #  70  |  Yumen CN
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=yumen
# ------------------------
# Proceesing: City #  71  |  Rikitea PF
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=rikitea
# ------------------------
# Proceesing: City #  72  |  Asyut EG
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=asyut
# ------------------------
# Proceesing: City #  73  |  Lircay PE
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=lircay
# ------------------------
# Proceesing: City #  74  |  Ribeira Grande PT
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=ribeira+grande
# ------------------------
# Proceesing: City #  75  |  Severo-Kurilsk RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=severo-kurilsk
# ------------------------
# Proceesing: City #  76  |  Saint-Pierre FR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=saint-pierre
# ------------------------
# Proceesing: City #  77  |  Howard Springs AU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=howard+springs
# ------------------------
# Proceesing: City #  78  |  Hasaki JP
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=hasaki
# ------------------------
# Proceesing: City #  79  |  Iqaluit CA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=iqaluit
# City not found, skipping...
# ------------------------
# Proceesing: City #  80  |  Bambous Virieux MU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=bambous+virieux
# ------------------------
# Proceesing: City #  81  |  Malakwal PK
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=malakwal
# ------------------------
# Proceesing: City #  82  |  Kodiak US
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=kodiak
# ------------------------
# Proceesing: City #  83  |  Pangnirtung CA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=pangnirtung
# ------------------------
# Proceesing: City #  84  |  Burnie AU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=burnie
# ------------------------
# Proceesing: City #  85  |  Tucuman PE
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=tucuman
# ------------------------
# Proceesing: City #  86  |  Malindi KE
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=malindi
# City not found, skipping...
# ------------------------
# Proceesing: City #  87  |  Carnarvon ZA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=carnarvon
# ------------------------
# Proceesing: City #  88  |  Ust-Nera RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=ust-nera
# ------------------------
# Proceesing: City #  89  |  Faanui PF
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=faanui
# ------------------------
# Proceesing: City #  90  |  Constitucion MX
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=constitucion
# ------------------------
# Proceesing: City #  91  |  Georgetown GY
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=georgetown
# ------------------------
# Proceesing: City #  92  |  Vila Franca do Campo PT
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=vila+franca+do+campo
# ------------------------
# Proceesing: City #  93  |  Coahuayana MX
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=coahuayana
# ------------------------
# Proceesing: City #  94  |  Klaksvik FO
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=klaksvik
# ------------------------
# Proceesing: City #  95  |  Pasni PK
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=pasni
# ------------------------
# Proceesing: City #  96  |  Akureyri IS
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=akureyri
# ------------------------
# Proceesing: City #  97  |  Thompson CA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=thompson
# ------------------------
# Proceesing: City #  98  |  Huntingdon GB
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=huntingdon
# ------------------------
# Proceesing: City #  99  |  Hilo US
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=hilo
# ------------------------
# Proceesing: City #  100  |  Svidnik SK
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=svidnik
# City not found, skipping...
# ------------------------
# Proceesing: City #  101  |  Mahajanga MG
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=mahajanga
# ------------------------
# Proceesing: City #  102  |  Namibe AO
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=namibe
# ------------------------
# Proceesing: City #  103  |  Vaini IN
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=vaini
# ------------------------
# Proceesing: City #  104  |  Buala SB
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=buala
# ------------------------
# Proceesing: City #  105  |  Chikwawa MW
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=chikwawa
# ------------------------
# Proceesing: City #  106  |  Iskateley RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=iskateley
# City not found, skipping...
# ------------------------
# Proceesing: City #  107  |  Tuktoyaktuk CA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=tuktoyaktuk
# ------------------------
# Proceesing: City #  108  |  Kodinsk RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=kodinsk
# ------------------------
# Proceesing: City #  109  |  Rancho Palos Verdes US
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=rancho+palos+verdes
# ------------------------
# Proceesing: City #  110  |  Bjornevatn NO
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=bjornevatn
# ------------------------
# Proceesing: City #  111  |  Srednekolymsk RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=srednekolymsk
# ------------------------
# Proceesing: City #  112  |  Saint-Philippe CA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=saint-philippe
# ------------------------
# Proceesing: City #  113  |  Santa Maria BR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=santa+maria
# City not found, skipping...
# ------------------------
# Proceesing: City #  114  |  Bethel US
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=bethel
# ------------------------
# Proceesing: City #  115  |  Tabory PL
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=tabory
# ------------------------
# Proceesing: City #  116  |  Isangel VU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=isangel
# ------------------------
# Proceesing: City #  117  |  Hermanus ZA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=hermanus
# City not found, skipping...
# City not found, skipping...
# ------------------------
# Proceesing: City #  118  |  Vila Velha BR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=vila+velha
# ------------------------
# Proceesing: City #  119  |  Ponta do Sol BR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=ponta+do+sol
# ------------------------
# Proceesing: City #  120  |  Jumla NP
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=jumla
# ------------------------
# Proceesing: City #  121  |  Inta RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=inta
# City not found, skipping...
# ------------------------
# Proceesing: City #  122  |  Hamilton CA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=hamilton
# ------------------------
# Proceesing: City #  123  |  Dvinskoy RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=dvinskoy
# ------------------------
# Proceesing: City #  124  |  Amapa HN
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=amapa
# ------------------------
# Proceesing: City #  125  |  Padang ID
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=padang
# ------------------------
# Proceesing: City #  126  |  Maxixe MZ
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=maxixe
# ------------------------
# Proceesing: City #  127  |  Hami CN
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=hami
# ------------------------
# Proceesing: City #  128  |  Ayaviri PE
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=ayaviri
# ------------------------
# Proceesing: City #  129  |  Butaritari KI
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=butaritari
# ------------------------
# Proceesing: City #  130  |  Hobyo SO
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=hobyo
# ------------------------
# Proceesing: City #  131  |  San Cristobal EC
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=san+cristobal
# ------------------------
# Proceesing: City #  132  |  Murgab TM
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=murgab
# ------------------------
# Proceesing: City #  133  |  Bilibino RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=bilibino
# ------------------------
# Proceesing: City #  134  |  Felanitx ES
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=felanitx
# ------------------------
# Proceesing: City #  135  |  Pundaguitan PH
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=pundaguitan
# ------------------------
# Proceesing: City #  136  |  Ostrovnoy RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=ostrovnoy
# ------------------------
# Proceesing: City #  137  |  Duncan US
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=duncan
# ------------------------
# Proceesing: City #  138  |  Pisco PE
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=pisco
# City not found, skipping...
# ------------------------
# Proceesing: City #  139  |  Marawi PH
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=marawi
# ------------------------
# Proceesing: City #  140  |  East London ZA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=east+london
# ------------------------
# Proceesing: City #  141  |  Conakry GN
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=conakry
# ------------------------
# Proceesing: City #  142  |  Inirida CO
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=inirida
# ------------------------
# Proceesing: City #  143  |  Bambanglipuro ID
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=bambanglipuro
# ------------------------
# Proceesing: City #  144  |  Banjarmasin ID
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=banjarmasin
# ------------------------
# Proceesing: City #  145  |  Ancud CL
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=ancud
# ------------------------
# Proceesing: City #  146  |  Tezu IN
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=tezu
# ------------------------
# Proceesing: City #  147  |  Kruisfontein ZA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=kruisfontein
# ------------------------
# Proceesing: City #  148  |  Esperance TT
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=esperance
# ------------------------
# Proceesing: City #  149  |  Viransehir TR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=viransehir
# ------------------------
# Proceesing: City #  150  |  Prince Rupert CA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=prince+rupert
# ------------------------
# Proceesing: City #  151  |  Sao Luiz Gonzaga BR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=sao+luiz+gonzaga
# ------------------------
# Proceesing: City #  152  |  Meulaboh ID
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=meulaboh
# ------------------------
# Proceesing: City #  153  |  Nizhniy Kuranakh RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=nizhniy+kuranakh
# ------------------------
# Proceesing: City #  154  |  Uige AO
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=uige
# ------------------------
# Proceesing: City #  155  |  Zenzeli RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=zenzeli
# ------------------------
# Proceesing: City #  156  |  Morgan City US
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=morgan+city
# ------------------------
# Proceesing: City #  157  |  Seoul KR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=seoul
# ------------------------
# Proceesing: City #  158  |  Wanning AT
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=wanning
# ------------------------
# Proceesing: City #  159  |  Gushikawa JP
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=gushikawa
# ------------------------
# Proceesing: City #  160  |  Boden SE
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=boden
# ------------------------
# Proceesing: City #  161  |  Houma CN
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=houma
# ------------------------
# Proceesing: City #  162  |  Luganville VU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=luganville
# ------------------------
# Proceesing: City #  163  |  Caravelas BR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=caravelas
# ------------------------
# Proceesing: City #  164  |  Kavieng PG
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=kavieng
# ------------------------
# Proceesing: City #  165  |  Nalut LY
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=nalut
# ------------------------
# Proceesing: City #  166  |  Flin Flon CA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=flin+flon
# ------------------------
# Proceesing: City #  167  |  Price US
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=price
# ------------------------
# Proceesing: City #  168  |  Nushki PK
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=nushki
# City not found, skipping...
# ------------------------
# Proceesing: City #  169  |  Luderitz NA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=luderitz
# ------------------------
# Proceesing: City #  170  |  Cherskiy RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=cherskiy
# ------------------------
# Proceesing: City #  171  |  Raudeberg NO
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=raudeberg
# ------------------------
# Proceesing: City #  172  |  Oranjestad AW
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=oranjestad
# ------------------------
# Proceesing: City #  173  |  San Patricio PY
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=san+patricio
# City not found, skipping...
# ------------------------
# Proceesing: City #  174  |  Bogorodskoye RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=bogorodskoye
# ------------------------
# Proceesing: City #  175  |  Mecca SA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=mecca
# ------------------------
# Proceesing: City #  176  |  Leningradskiy RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=leningradskiy
# City not found, skipping...
# ------------------------
# Proceesing: City #  177  |  Meadow Lake CA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=meadow+lake
# ------------------------
# Proceesing: City #  178  |  Husavik CA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=husavik
# ------------------------
# Proceesing: City #  179  |  Camacha PT
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=camacha
# ------------------------
# Proceesing: City #  180  |  Geraldton CA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=geraldton
# ------------------------
# Proceesing: City #  181  |  Broken Hill AU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=broken+hill
# City not found, skipping...
# ------------------------
# Proceesing: City #  182  |  Ihosy MG
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=ihosy
# ------------------------
# Proceesing: City #  183  |  Tilik PH
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=tilik
# ------------------------
# Proceesing: City #  184  |  Mbala ZM
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=mbala
# ------------------------
# Proceesing: City #  185  |  Vestmannaeyjar IS
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=vestmannaeyjar
# City not found, skipping...
# ------------------------
# Proceesing: City #  186  |  Lavrentiya RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=lavrentiya
# ------------------------
# Proceesing: City #  187  |  Saint Anthony US
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=saint+anthony
# ------------------------
# Proceesing: City #  188  |  Merauke ID
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=merauke
# City not found, skipping...
# ------------------------
# Proceesing: City #  189  |  Chokurdakh RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=chokurdakh
# ------------------------
# Proceesing: City #  190  |  Wilmington US
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=wilmington
# ------------------------
# Proceesing: City #  191  |  Lubumbashi CD
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=lubumbashi
# ------------------------
# Proceesing: City #  192  |  Eyl SO
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=eyl
# City not found, skipping...
# ------------------------
# Proceesing: City #  193  |  Bansang GM
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=bansang
# ------------------------
# Proceesing: City #  194  |  Arona IT
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=arona
# ------------------------
# Proceesing: City #  195  |  Port Augusta AU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=port+augusta
# ------------------------
# Proceesing: City #  196  |  Floriano BR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=floriano
# ------------------------
# Proceesing: City #  197  |  Beloha MG
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=beloha
# ------------------------
# Proceesing: City #  198  |  Praya ID
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=praya
# City not found, skipping...
# ------------------------
# Proceesing: City #  199  |  Yashan CN
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=yashan
# ------------------------
# Proceesing: City #  200  |  Sao Filipe CV
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=sao+filipe
# ------------------------
# Proceesing: City #  201  |  Hualmay PE
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=hualmay
# ------------------------
# Proceesing: City #  202  |  Ozernovskiy RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=ozernovskiy
# ------------------------
# Proceesing: City #  203  |  Hammerfest NO
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=hammerfest
# ------------------------
# Proceesing: City #  204  |  Upernavik GL
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=upernavik
# ------------------------
# Proceesing: City #  205  |  Balabac PH
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=balabac
# City not found, skipping...
# ------------------------
# Proceesing: City #  206  |  Yakovlevskoye RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=yakovlevskoye
# ------------------------
# Proceesing: City #  207  |  Rawlins US
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=rawlins
# City not found, skipping...
# ------------------------
# Proceesing: City #  208  |  Aktau KZ
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=aktau
# ------------------------
# Proceesing: City #  209  |  Mayo CA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=mayo
# ------------------------
# Proceesing: City #  210  |  Suntar RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=suntar
# ------------------------
# Proceesing: City #  211  |  Haimen CN
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=haimen
# ------------------------
# Proceesing: City #  212  |  Eureka US
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=eureka
# ------------------------
# Proceesing: City #  213  |  Floro NO
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=floro
# ------------------------
# Proceesing: City #  214  |  San Vicente SV
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=san+vicente
# ------------------------
# Proceesing: City #  215  |  Hervey Bay AU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=hervey+bay
# ------------------------
# Proceesing: City #  216  |  Paptalaya HN
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=paptalaya
# ------------------------
# Proceesing: City #  217  |  Nanortalik GL
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=nanortalik
# ------------------------
# Proceesing: City #  218  |  Kamaishi JP
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=kamaishi
# ------------------------
# Proceesing: City #  219  |  Mount Isa AU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=mount+isa
# ------------------------
# Proceesing: City #  220  |  Tam Ky VN
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=tam+ky
# ------------------------
# Proceesing: City #  221  |  Ilulissat GL
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=ilulissat
# ------------------------
# Proceesing: City #  222  |  Nome US
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=nome
# ------------------------
# Proceesing: City #  223  |  Eirunepe BR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=eirunepe
# ------------------------
# Proceesing: City #  224  |  Cidreira BR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=cidreira
# ------------------------
# Proceesing: City #  225  |  Ploemeur FR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=ploemeur
# ------------------------
# Proceesing: City #  226  |  Oer-Erkenschwick DE
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=oer-erkenschwick
# ------------------------
# Proceesing: City #  227  |  Talnakh RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=talnakh
# ------------------------
# Proceesing: City #  228  |  Sept-Iles CA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=sept-iles
# ------------------------
# Proceesing: City #  229  |  Salalah OM
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=salalah
# ------------------------
# Proceesing: City #  230  |  Moron VE
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=moron
# ------------------------
# Proceesing: City #  231  |  Port Keats AU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=port+keats
# ------------------------
# Proceesing: City #  232  |  Bulri PK
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=bulri
# ------------------------
# Proceesing: City #  233  |  Nurota UZ
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=nurota
# ------------------------
# Proceesing: City #  234  |  New Bedford US
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=new+bedford
# City not found, skipping...
# ------------------------
# Proceesing: City #  235  |  Ginir ET
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=ginir
# ------------------------
# Proceesing: City #  236  |  Mayumba GA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=mayumba
# ------------------------
# Proceesing: City #  237  |  Dikson RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=dikson
# ------------------------
# Proceesing: City #  238  |  Qaqortoq GL
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=qaqortoq
# ------------------------
# Proceesing: City #  239  |  Bilma NE
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=bilma
# ------------------------
# Proceesing: City #  240  |  Necochea AR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=necochea
# ------------------------
# Proceesing: City #  241  |  Los Llanos de Aridane ES
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=los+llanos+de+aridane
# ------------------------
# Proceesing: City #  242  |  Nkayi CG
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=nkayi
# ------------------------
# Proceesing: City #  243  |  Vitry-le-Francois FR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=vitry-le-francois
# ------------------------
# Proceesing: City #  244  |  Babushkin RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=babushkin
# ------------------------
# Proceesing: City #  245  |  Rio Claro BR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=rio+claro
# ------------------------
# Proceesing: City #  246  |  Olinda EC
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=olinda
# ------------------------
# Proceesing: City #  247  |  Ayagoz KZ
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=ayagoz
# ------------------------
# Proceesing: City #  248  |  Trinidad UY
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=trinidad
# ------------------------
# Proceesing: City #  249  |  Kalabo ZM
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=kalabo
# ------------------------
# Proceesing: City #  250  |  Arlit NE
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=arlit
# ------------------------
# Proceesing: City #  251  |  Tessalit ML
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=tessalit
# ------------------------
# Proceesing: City #  252  |  Buin CL
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=buin
# ------------------------
# Proceesing: City #  253  |  Quatre Cocos MU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=quatre+cocos
# ------------------------
# Proceesing: City #  254  |  Darnah LY
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=darnah
# ------------------------
# Proceesing: City #  255  |  Francisco Beltrao BR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=francisco+beltrao
# ------------------------
# Proceesing: City #  256  |  Evensk RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=evensk
# ...
# Proceesing: City #  535  |  Yanam IN
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=yanam
# ------------------------
# Proceesing: City #  536  |  Martapura ID
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=martapura
# ------------------------
# Proceesing: City #  537  |  Harper US
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=harper
# ------------------------
# Proceesing: City #  538  |  Quelimane MZ
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=quelimane
# City not found, skipping...
# ------------------------
# Proceesing: City #  539  |  Chopda IN
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=chopda
# City not found, skipping...
# ------------------------
# Proceesing: City #  540  |  Mitsamiouli KM
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=mitsamiouli
# City not found, skipping...
# ------------------------
# Proceesing: City #  541  |  LaBelle US
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=labelle
# ------------------------
# Proceesing: City #  542  |  Rafraf TN
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=rafraf
# ------------------------
# Proceesing: City #  543  |  Enid US
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=enid
# ------------------------
# Proceesing: City #  544  |  Brae GB
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=brae
# ------------------------
# Proceesing: City #  545  |  Karacakoy TR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=karacakoy
# ------------------------
# Proceesing: City #  546  |  Kuryk KZ
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=kuryk
# City not found, skipping...
# ------------------------
# Proceesing: City #  547  |  San Antero CO
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=san+antero
# ------------------------
# Proceesing: City #  548  |  Pavelets RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=pavelets
# ------------------------
# Proceesing: City #  549  |  Santa Cruz US
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=santa+cruz
# ------------------------
# Proceesing: City #  550  |  Moussoro TD
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=moussoro
# ------------------------
# Proceesing: City #  551  |  Weligama LK
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=weligama
# ------------------------
# Proceesing: City #  552  |  Nelson Bay AU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=nelson+bay
# ------------------------
# Proceesing: City #  553  |  Gat SN
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=gat
# ------------------------
# Proceesing: City #  554  |  Mareeba AU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=mareeba
# ------------------------
# Proceesing: City #  555  |  Arvi IN
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=arvi
# ------------------------
# Proceesing: City #  556  |  Tuim RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=tuim
# ------------------------
# Proceesing: City #  557  |  Baruun-Urt MN
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=baruun-urt
# ------------------------
# Proceesing: City #  558  |  Balezino RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=balezino
# ------------------------
# Proceesing: City #  559  |  Lasem ID
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=lasem
# City not found, skipping...
# ------------------------
# Proceesing: City #  560  |  Edd ER
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=edd
# ------------------------
# Proceesing: City #  561  |  Skelleftea SE
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=skelleftea
# ------------------------
# Proceesing: City #  562  |  Burgeo CA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=burgeo
# ------------------------
# Proceesing: City #  563  |  Poum MK
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=poum
# ------------------------
# Proceesing: City #  564  |  Waingapu ID
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=waingapu
# ------------------------
# Proceesing: City #  565  |  Avdon IL
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=avdon
# ------------------------
# Proceesing: City #  566  |  Lere TD
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=lere
# City not found, skipping...
# ------------------------
# Proceesing: City #  567  |  Bontang ID
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=bontang
# ------------------------
# Proceesing: City #  568  |  Lakatoro VU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=lakatoro
# ------------------------
# Proceesing: City #  569  |  Huayucachi PE
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=huayucachi
# ------------------------
# Proceesing: City #  570  |  Nioro GM
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=nioro
# ------------------------
# Proceesing: City #  571  |  Pontianak ID
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=pontianak
# ------------------------
# Proceesing: City #  572  |  Teguldet RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=teguldet
# ------------------------
# Proceesing: City #  573  |  Bitung ID
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=bitung
# ------------------------
# Proceesing: City #  574  |  Itaqui BR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=itaqui
# ------------------------
# Proceesing: City #  575  |  Canton US
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=canton
# ------------------------
# Proceesing: City #  576  |  Taunggyi MM
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=taunggyi
# ------------------------
# Proceesing: City #  577  |  Kaeo NZ
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=kaeo
# ------------------------
# Proceesing: City #  578  |  Huntsville US
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=huntsville
# ------------------------
# Proceesing: City #  579  |  Wainwright CA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=wainwright
# ------------------------
# Proceesing: City #  580  |  Uyemskiy RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=uyemskiy
# ------------------------
# Proceesing: City #  581  |  Taoudenni ML
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=taoudenni
# ------------------------
# Proceesing: City #  582  |  Winnemucca US
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=winnemucca
# ------------------------
# Proceesing: City #  583  |  Port Blair IN
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=port+blair
# ------------------------
# Proceesing: City #  584  |  Mutoko ZW
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=mutoko
# ------------------------
# Proceesing: City #  585  |  Den Helder NL
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=den+helder
# ------------------------
# Proceesing: City #  586  |  New Castle US
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=new+castle
# ------------------------
# Proceesing: City #  587  |  Kiama AU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=kiama
# ------------------------
# Proceesing: City #  588  |  Acapulco MX
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=acapulco
# ------------------------
# Proceesing: City #  589  |  Bull Savanna JM
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=bull+savanna
# ------------------------
# Proceesing: City #  590  |  Sinnamary GF
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=sinnamary
# ------------------------
# Proceesing: City #  591  |  Senador Guiomard BR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=senador+guiomard
# ------------------------
# Proceesing: City #  592  |  Henties Bay NA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=henties+bay
# ------------------------
# Proceesing: City #  593  |  Sur OM
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=sur
# ------------------------
# Proceesing: City #  594  |  Xixiang CN
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=xixiang
# ------------------------
# Proceesing: City #  595  |  Nortelandia BR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=nortelandia
# ------------------------
# Proceesing: City #  596  |  Whyalla AU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=whyalla
# ------------------------
# Proceesing: City #  597  |  Touros BR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=touros
# ------------------------
# Proceesing: City #  598  |  Sao Felix do Xingu BR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=sao+felix+do+xingu
# ------------------------
# Proceesing: City #  599  |  Rehli IN
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=rehli
# ------------------------
# Proceesing: City #  600  |  Arman RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=arman
# ------------------------
# Proceesing: City #  601  |  Conceicao do Araguaia BR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=conceicao+do+araguaia
# ------------------------
# Proceesing: City #  602  |  Tongchuan CN
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=tongchuan
# ------------------------
# Proceesing: City #  603  |  Thinadhoo MV
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=thinadhoo
# ------------------------
# Proceesing: City #  604  |  Guskhara IN
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=guskhara
# ------------------------
# Proceesing: City #  605  |  Bima ID
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=bima
# City not found, skipping...
# ------------------------
# Proceesing: City #  606  |  Gazipur BD
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=gazipur
# ------------------------
# Proceesing: City #  607  |  Hokitika NZ
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=hokitika
# ------------------------
# Proceesing: City #  608  |  Dukat RS
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=dukat
# ------------------------
# Proceesing: City #  609  |  Vostok RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=vostok
# City not found, skipping...
# ------------------------
# Proceesing: City #  610  |  Humberto de Campos BR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=humberto+de+campos
# ------------------------
# Proceesing: City #  611  |  Gao ML
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=gao
# ------------------------
# Proceesing: City #  612  |  Novobirilyussy RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=novobirilyussy
# ------------------------
# Proceesing: City #  613  |  Ancona US
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=ancona
# ------------------------
# Proceesing: City #  614  |  Salinopolis BR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=salinopolis
# ------------------------
# Proceesing: City #  615  |  Severomuysk RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=severomuysk
# ------------------------
# Proceesing: City #  616  |  Bratsk RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=bratsk
# ------------------------
# Proceesing: City #  617  |  Dali CN
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=dali
# ------------------------
# Proceesing: City #  618  |  Nuevo Progreso US
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=nuevo+progreso
# ------------------------
# Proceesing: City #  619  |  Coihaique CL
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=coihaique
# ------------------------
# Proceesing: City #  620  |  Port Hawkesbury CA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=port+hawkesbury
# ------------------------
# Proceesing: City #  621  |  Kloulklubed PW
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=kloulklubed
# ------------------------
# Proceesing: City #  622  |  Pahrump US
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=pahrump
# City not found, skipping...
# ------------------------
# Proceesing: City #  623  |  Rosarito CO
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=rosarito

# %% [markdown]
# ## Perform API Calls

# %%
clean_cities_df.count()
# Out:
# City                623
# Country             623
# Temperature (F)     623
# Latitude            623
# Longitude           623
# Humidity (%)        623
# Cloudiness (%)      623
# Wind Speed (mph)    623
# dtype: int64

# %%
clean_cities_df = clean_cities_df.reset_index()
del clean_cities_df['index']
clean_cities_df.head(25)
# Out:
#                   City Country Temperature (F) Latitude Longitude  \
# 0         Punta Arenas      CL            42.8   -53.16    -70.91
# 1            Havoysund      NO           49.98       71     24.66
# 2                Roald      NO           45.88    62.58      6.12
# 3            Batsfjord      NO           56.32    70.63     29.72
# 4                 Hofn      IS           49.07    64.25    -15.21
# 5                Alofi      NU            78.8   -19.06   -169.92
# 6                Marau      BR            75.2   -28.45     -52.2
# 7            Busselton      AU           54.56   -33.64    115.35
# 8           Filadelfia      PY           96.86   -22.35    -60.04
# 9              Qaanaaq      GL           33.23    77.48    -69.36
# 10         Weatherford      US           95.11    32.76     -97.8
# 11           Kavaratti      IN           80.84    10.57     72.64
# 12              Torbay      CA              59    47.66    -52.73
# 13             Segamat      MY              77     2.51    102.82
# 14           Saskylakh      RU           41.42    71.97    114.09
# 15           Jamestown      AU           47.09   -33.21     138.6
# 16      Krasnyy Chikoy      RU           47.27    50.36    108.75
# 17            Saldanha      PT           64.19    41.42     -6.55
# 18               Airai      TL           66.53    -8.93    125.41
# 19              Yulara      AU            44.6   -25.24    130.99
# 20             Ushuaia      AR           40.42   -54.81    -68.31
# 21               Praia      BR            73.4   -20.25    -43.81
# 22  Severo-Yeniseyskiy      RU           49.52    60.37     93.04
# 23         New Norfolk      AU            46.4   -42.78    147.06
# 24        Sao Domingos      BR           80.39    -13.4    -46.32
#
#    Humidity (%) Cloudiness (%) Wind Speed (mph)
# 0            93             40             20.8
# 1            81             75             2.24
# 2            93              0             1.12
# 3            62              0            29.97
# 4            98             92             18.9
# 5            74             75            14.99
# 6            69             40             9.17
# 7           100             76            10.96
# 8            30              0            19.35
# 9           100              0              2.8
# 10           35              1             6.93
# 11          100             32             14.2
# 12           77             75            21.92
# 13           94             75             3.36
# 14           92             68            13.76
# 15           99             92            15.66
# 16           92             24             2.13
# 17           74              0             2.68
# 18           96             56             1.68
# 19           48              0             6.93
# 20           86             75            24.16
# 21           43              0             6.93
# 22           93             76             3.02
# 23           87             75             5.82
# 24           32              0             9.95

# %%
plt.scatter(clean_cities_df["Latitude"], 
            clean_cities_df["Temperature (F)"], c=clean_cities_df["Temperature (F)"],
            edgecolor="black", linewidths=1, marker="o", 
            cmap='plasma', alpha=0.8, label="City")

# Incorporate the other graph properties
plt.style.use('seaborn')
plt.title(f"City Latitude vs. Max Temperature {datetime.now().strftime('%m/%d/%Y')}")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-80, 100])
plt.ylim([-60, 120])

# Save the figure
plt.savefig("Latitude_Temperature.png")

# Show plot
plt.show()

# %%
#Build a scatter plot for Latitude vs. Humidity (%)

plt.scatter(clean_cities_df["Latitude"], 
            clean_cities_df["Humidity (%)"], c=clean_cities_df["Humidity (%)"],
            edgecolor="black", linewidths=1, marker="o", 
            cmap='GnBu', alpha=0.8, label="City")

# Incorporate the other graph properties
plt.style.use('seaborn')
plt.title(f"City Latitude vs. Humidity (%) {datetime.now().strftime('%m/%d/%Y')}")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-80, 100])
plt.ylim([-5, 125])

# Save the figure
plt.savefig("Latitude_Humidity.png")

# Show plot
plt.show()

# %%
#Build a scatter plot for Latitude vs. Cloudiness (%)#Build a 

plt.scatter(clean_cities_df["Latitude"], 
            clean_cities_df["Cloudiness (%)"], c=clean_cities_df["Cloudiness (%)"],
            edgecolor="black", linewidths=1, marker="o", 
            cmap='bone_r', alpha=0.8, label="City")

# Incorporate the other graph properties
plt.style.use('seaborn')
plt.title(f"City Latitude vs. Cloudiness (%) {datetime.now().strftime('%m/%d/%Y')}")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-80, 100])
plt.ylim([-10, 125])

# Save the figure
plt.savefig("Latitude_Cloudiness.png")

# Show plot
plt.show()

# %%
#Build a scatter plot for Latitude vs. Wind Speed (mph)

plt.scatter(clean_cities_df["Latitude"], 
            clean_cities_df["Wind Speed (mph)"], c=clean_cities_df["Wind Speed (mph)"],
            edgecolor="black", linewidths=1, marker="o", 
            cmap='Spectral_r', alpha=0.8, label="City")

# Incorporate the other graph properties
plt.style.use('seaborn')
plt.title(f"City Latitude vs. Wind Speed (mph) {datetime.now().strftime('%m/%d/%Y')}")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-80, 100])
plt.ylim([-10, 50])

# Save the figure
plt.savefig("Latitude_WindSpeed.png")

# Show plot
plt.show()

# %%
#Build a scatter plot for Latitude vs. Wind Speed (mph)

plt.scatter(clean_cities_df["Longitude"], 
            clean_cities_df["Latitude"], c=clean_cities_df["Latitude"],
            edgecolor="black", linewidths=1, marker="o", 
            cmap='RdYlBu', alpha=0.8, label="City")

# Incorporate the other graph properties
plt.style.use('seaborn')
plt.title(f"Longitude vs. Latitude {datetime.now().strftime('%m/%d/%Y')}")
plt.ylabel("Latitude")
plt.xlabel("Longitude")
plt.grid(True)
plt.xlim([-200, 200])
plt.ylim([-80, 100])

# Save the figure
plt.savefig("Latitude_Longitude.png")

# Show plot
plt.show()
