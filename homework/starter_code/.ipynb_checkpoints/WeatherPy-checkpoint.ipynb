# %%
# After examining the plots it is clear to see that the temperature does increase the closer you get to the equator.
## my last graph looks like a world map!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
from citipy import citipy
from datetime import datetime
from random import uniform


# Create a df to lat, lon 
column_names = ["City", "Country"]
cities_df = pd.DataFrame(columns=column_names)

api_key = "d6810bdaefe467cd40907ae8b7ed7c10"

# %% [markdown]
# ## Generate Cities List

# %%
# Randomly generate a list of 1750 cities. Use 50 to test for duplicates.
for x in range(1750):
    lat, lng = np.random.uniform(low=-90.000, high=90.000), np.random.uniform(low=-180.000, high=180.000)
    city = citipy.nearest_city(lat, lng)
    cities_df = cities_df.append({"City": city.city_name,"Country": city.country_code,}, ignore_index=True)

#Remove duplicate cities
cities_df = cities_df.drop_duplicates(subset='City').reset_index()
cities_df.count()
# Out:
# index      677
# City       677
# Country    677
# dtype: int64

# %%
#Create a df to add all the data from the API calls.
column_names = ["City", "Country","Temperature (F)",
                "Latitude","Longitude","Humidity (%)",
                "Cloudiness (%)", "Wind Speed (mph)"]
clean_cities_df = pd.DataFrame(columns=column_names)

# Loop through the list of cities and add the data to the df.
url = "http://api.openweathermap.org/data/2.5/weather?"

row_count = 1

print("Beginning Data Retrieval")
for index, row in cities_df.iterrows():
    target_city = row["City"]
    target_url = url + "appid=" + api_key + "&units=IMPERIAL" + "&q=" + target_city.replace(" ","+")
    city_data = requests.get(target_url).json()
    if city_data["cod"] == "404":
        print("City not found, skipping...")

    else:
        clean_cities_df.set_value(index, "City", city_data["name"])
        clean_cities_df.set_value(index, "Country", city_data["sys"]["country"])
        clean_cities_df.set_value(index, "Temperature (F)", city_data["main"]["temp"])
        clean_cities_df.set_value(index, "Latitude", city_data["coord"]["lat"])
        clean_cities_df.set_value(index, "Longitude", city_data["coord"]["lon"])
        clean_cities_df.set_value(index, "Humidity (%)", city_data["main"]["humidity"])
        clean_cities_df.set_value(index, "Cloudiness (%)", city_data["clouds"]["all"])
        clean_cities_df.set_value(index, "Wind Speed (mph)", city_data["wind"]["speed"])
        
        print("------------------------")
        print("Proceesing: City # " , row_count, ' | ' , city_data["name"], city_data["sys"]["country"])
        print(target_url)
        row_count += 1
# Out:
# Beginning Data Retrieval
# C:\Users\raman\Anaconda3\envs\PythonData\lib\site-packages\ipykernel\__main__.py:21: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\raman\Anaconda3\envs\PythonData\lib\site-packages\ipykernel\__main__.py:22: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\raman\Anaconda3\envs\PythonData\lib\site-packages\ipykernel\__main__.py:23: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\raman\Anaconda3\envs\PythonData\lib\site-packages\ipykernel\__main__.py:24: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\raman\Anaconda3\envs\PythonData\lib\site-packages\ipykernel\__main__.py:25: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\raman\Anaconda3\envs\PythonData\lib\site-packages\ipykernel\__main__.py:26: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\raman\Anaconda3\envs\PythonData\lib\site-packages\ipykernel\__main__.py:27: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\raman\Anaconda3\envs\PythonData\lib\site-packages\ipykernel\__main__.py:28: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# ------------------------
# Proceesing: City #  1  |  Kapaa US
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=kapaa
# ------------------------
# Proceesing: City #  2  |  Sistranda NO
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=sistranda
# ------------------------
# Proceesing: City #  3  |  New Norfolk AU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=new+norfolk
# ------------------------
# Proceesing: City #  4  |  Katwijk NL
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=katwijk
# ------------------------
# Proceesing: City #  5  |  Makakilo City US
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=makakilo+city
# ------------------------
# Proceesing: City #  6  |  Castro CL
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=castro
# ------------------------
# Proceesing: City #  7  |  Port Alfred ZA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=port+alfred
# ------------------------
# Proceesing: City #  8  |  Saint George GR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=saint+george
# ------------------------
# Proceesing: City #  9  |  Victor Harbor AU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=victor+harbor
# ------------------------
# Proceesing: City #  10  |  Matara PE
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=matara
# ------------------------
# Proceesing: City #  11  |  Albany US
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=albany
# ------------------------
# Proceesing: City #  12  |  Port Elizabeth US
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=port+elizabeth
# ------------------------
# Proceesing: City #  13  |  Hobart AU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=hobart
# ------------------------
# Proceesing: City #  14  |  Haines Junction CA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=haines+junction
# ------------------------
# Proceesing: City #  15  |  Green River US
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=green+river
# ------------------------
# Proceesing: City #  16  |  Iqaluit CA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=iqaluit
# ------------------------
# Proceesing: City #  17  |  Seoul KR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=seoul
# ------------------------
# Proceesing: City #  18  |  La Orilla MX
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=la+orilla
# City not found, skipping...
# ------------------------
# Proceesing: City #  19  |  Cockburn Town TC
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=cockburn+town
# ------------------------
# Proceesing: City #  20  |  Rikitea PF
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=rikitea
# ------------------------
# Proceesing: City #  21  |  Severo-Kurilsk RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=severo-kurilsk
# ------------------------
# Proceesing: City #  22  |  Victoria BN
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=victoria
# ------------------------
# Proceesing: City #  23  |  Bluff AU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=bluff
# City not found, skipping...
# ------------------------
# Proceesing: City #  24  |  Pacifica US
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=pacifica
# ------------------------
# Proceesing: City #  25  |  Bethel US
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=bethel
# ------------------------
# Proceesing: City #  26  |  Belaya Gora RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=belaya+gora
# ------------------------
# Proceesing: City #  27  |  East London ZA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=east+london
# ------------------------
# Proceesing: City #  28  |  Cape Town ZA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=cape+town
# ------------------------
# Proceesing: City #  29  |  Avarua CK
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=avarua
# ------------------------
# Proceesing: City #  30  |  Pitimbu BR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=pitimbu
# ------------------------
# Proceesing: City #  31  |  Mpika ZM
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=mpika
# ------------------------
# Proceesing: City #  32  |  Buin CL
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=buin
# ------------------------
# Proceesing: City #  33  |  Deputatskiy RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=deputatskiy
# City not found, skipping...
# ------------------------
# Proceesing: City #  34  |  Katsuura JP
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=katsuura
# ------------------------
# Proceesing: City #  35  |  Bredasdorp ZA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=bredasdorp
# ------------------------
# Proceesing: City #  36  |  Kerman IR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=kerman
# City not found, skipping...
# ------------------------
# Proceesing: City #  37  |  Avera US
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=avera
# ------------------------
# Proceesing: City #  38  |  Punta Arenas CL
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=punta+arenas
# ------------------------
# Proceesing: City #  39  |  Bambanglipuro ID
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=bambanglipuro
# ------------------------
# Proceesing: City #  40  |  Ahipara NZ
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=ahipara
# ------------------------
# Proceesing: City #  41  |  Lebu ET
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=lebu
# ------------------------
# Proceesing: City #  42  |  Qaanaaq GL
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=qaanaaq
# ------------------------
# Proceesing: City #  43  |  Wilmington US
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=wilmington
# City not found, skipping...
# ------------------------
# Proceesing: City #  44  |  Vinukonda IN
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=vinukonda
# City not found, skipping...
# ------------------------
# Proceesing: City #  45  |  Noumea NC
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=noumea
# City not found, skipping...
# City not found, skipping...
# ------------------------
# Proceesing: City #  46  |  Ucluelet CA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=ucluelet
# ------------------------
# Proceesing: City #  47  |  Caxito BR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=caxito
# ------------------------
# Proceesing: City #  48  |  Sangin AF
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=sangin
# ------------------------
# Proceesing: City #  49  |  Butaritari KI
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=butaritari
# ------------------------
# Proceesing: City #  50  |  Aklavik CA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=aklavik
# ------------------------
# Proceesing: City #  51  |  Vilhena BR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=vilhena
# ------------------------
# Proceesing: City #  52  |  Hermanus ZA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=hermanus
# ------------------------
# Proceesing: City #  53  |  Shimoda JP
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=shimoda
# ------------------------
# Proceesing: City #  54  |  Nuuk GL
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=nuuk
# ------------------------
# Proceesing: City #  55  |  Tezu IN
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=tezu
# ------------------------
# Proceesing: City #  56  |  Oum Hadjer TD
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=oum+hadjer
# ------------------------
# Proceesing: City #  57  |  Kavieng PG
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=kavieng
# City not found, skipping...
# ------------------------
# Proceesing: City #  58  |  Isangel VU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=isangel
# ------------------------
# Proceesing: City #  59  |  Zhigansk RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=zhigansk
# City not found, skipping...
# City not found, skipping...
# ------------------------
# Proceesing: City #  60  |  Hithadhoo MV
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=hithadhoo
# ------------------------
# Proceesing: City #  61  |  Busselton AU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=busselton
# ------------------------
# Proceesing: City #  62  |  Qaqortoq GL
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=qaqortoq
# ------------------------
# Proceesing: City #  63  |  Bathsheba BB
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=bathsheba
# ------------------------
# Proceesing: City #  64  |  Barrow AR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=barrow
# ------------------------
# Proceesing: City #  65  |  Airai TL
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=airai
# ------------------------
# Proceesing: City #  66  |  Nizwa OM
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=nizwa
# ------------------------
# Proceesing: City #  67  |  Sidney US
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=sidney
# ------------------------
# Proceesing: City #  68  |  Tiksi RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=tiksi
# ------------------------
# Proceesing: City #  69  |  Maceio BR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=maceio
# ------------------------
# Proceesing: City #  70  |  Yingkou CN
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=yingkou
# ------------------------
# Proceesing: City #  71  |  Nanga Eboko CM
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=nanga+eboko
# ------------------------
# Proceesing: City #  72  |  Saint-Joseph FR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=saint-joseph
# ------------------------
# Proceesing: City #  73  |  Ushuaia AR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=ushuaia
# ------------------------
# Proceesing: City #  74  |  Voineasa RO
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=voineasa
# ------------------------
# Proceesing: City #  75  |  Tours FR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=tours
# ------------------------
# Proceesing: City #  76  |  Narsaq GL
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=narsaq
# ------------------------
# Proceesing: City #  77  |  Longyearbyen NO
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=longyearbyen
# City not found, skipping...
# City not found, skipping...
# ------------------------
# Proceesing: City #  78  |  Upernavik GL
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=upernavik
# ------------------------
# Proceesing: City #  79  |  Quesnel CA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=quesnel
# ------------------------
# Proceesing: City #  80  |  Mataura NZ
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=mataura
# ------------------------
# Proceesing: City #  81  |  Pochutla MX
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=pochutla
# City not found, skipping...
# ------------------------
# Proceesing: City #  82  |  Hilo US
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=hilo
# ------------------------
# Proceesing: City #  83  |  Port Macquarie AU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=port+macquarie
# ------------------------
# Proceesing: City #  84  |  Hammerfest NO
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=hammerfest
# ------------------------
# Proceesing: City #  85  |  Salalah OM
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=salalah
# ------------------------
# Proceesing: City #  86  |  Vao EE
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=vao
# ------------------------
# Proceesing: City #  87  |  Vaini IN
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=vaini
# ------------------------
# Proceesing: City #  88  |  Saint-Philippe CA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=saint-philippe
# ------------------------
# Proceesing: City #  89  |  Gravdal NO
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=gravdal
# ------------------------
# Proceesing: City #  90  |  Dikson RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=dikson
# ------------------------
# Proceesing: City #  91  |  Meulaboh ID
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=meulaboh
# ------------------------
# Proceesing: City #  92  |  Arraial do Cabo BR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=arraial+do+cabo
# ------------------------
# Proceesing: City #  93  |  Manokwari ID
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=manokwari
# ------------------------
# Proceesing: City #  94  |  Areia Branca BR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=areia+branca
# ------------------------
# Proceesing: City #  95  |  Chokurdakh RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=chokurdakh
# ------------------------
# Proceesing: City #  96  |  Kon Tum VN
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=kon+tum
# ------------------------
# Proceesing: City #  97  |  Chuy UY
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=chuy
# ------------------------
# Proceesing: City #  98  |  Urgut UZ
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=urgut
# ------------------------
# Proceesing: City #  99  |  Thompson CA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=thompson
# ------------------------
# Proceesing: City #  100  |  Antofagasta CL
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=antofagasta
# ------------------------
# Proceesing: City #  101  |  Atuona PF
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=atuona
# ------------------------
# Proceesing: City #  102  |  Batagay-Alyta RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=batagay-alyta
# City not found, skipping...
# ------------------------
# Proceesing: City #  103  |  Bemidji US
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=bemidji
# ------------------------
# Proceesing: City #  104  |  Yulara AU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=yulara
# ------------------------
# Proceesing: City #  105  |  Broken Hill AU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=broken+hill
# ------------------------
# Proceesing: City #  106  |  Natal BR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=natal
# ------------------------
# Proceesing: City #  107  |  Orapa BW
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=orapa
# ------------------------
# Proceesing: City #  108  |  Labuhan ID
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=labuhan
# ------------------------
# Proceesing: City #  109  |  Burnie AU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=burnie
# ------------------------
# Proceesing: City #  110  |  Paamiut GL
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=paamiut
# ------------------------
# Proceesing: City #  111  |  Puerto del Rosario ES
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=puerto+del+rosario
# ------------------------
# Proceesing: City #  112  |  Dhidhdhoo MV
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=dhidhdhoo
# ------------------------
# Proceesing: City #  113  |  Biggar GB
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=biggar
# ------------------------
# Proceesing: City #  114  |  Verkhoyansk RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=verkhoyansk
# ------------------------
# Proceesing: City #  115  |  Henties Bay NA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=henties+bay
# ------------------------
# Proceesing: City #  116  |  Tuktoyaktuk CA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=tuktoyaktuk
# ------------------------
# Proceesing: City #  117  |  Cayenne GF
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=cayenne
# ------------------------
# Proceesing: City #  118  |  Semnan IR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=semnan
# ------------------------
# Proceesing: City #  119  |  Santa Isabel do Rio Negro BR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=santa+isabel+do+rio+negro
# ------------------------
# Proceesing: City #  120  |  Foam Lake CA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=foam+lake
# ------------------------
# Proceesing: City #  121  |  Cidreira BR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=cidreira
# City not found, skipping...
# ------------------------
# Proceesing: City #  122  |  Sechura PE
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=sechura
# ------------------------
# Proceesing: City #  123  |  Zinacantan MX
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=zinacantan
# City not found, skipping...
# ------------------------
# Proceesing: City #  124  |  Cabo San Lucas MX
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=cabo+san+lucas
# ------------------------
# Proceesing: City #  125  |  Hamilton BM
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=hamilton
# ------------------------
# Proceesing: City #  126  |  Buala SB
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=buala
# ------------------------
# Proceesing: City #  127  |  Khatanga RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=khatanga
# ------------------------
# Proceesing: City #  128  |  Cape Coast GH
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=cape+coast
# ------------------------
# Proceesing: City #  129  |  Sao Filipe CV
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=sao+filipe
# ------------------------
# Proceesing: City #  130  |  Faya SA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=faya
# ------------------------
# Proceesing: City #  131  |  Saskylakh RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=saskylakh
# ------------------------
# Proceesing: City #  132  |  Jamestown AU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=jamestown
# ------------------------
# Proceesing: City #  133  |  Yellowknife CA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=yellowknife
# City not found, skipping...
# ------------------------
# Proceesing: City #  134  |  Nerchinskiy Zavod RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=nerchinskiy+zavod
# ------------------------
# Proceesing: City #  135  |  Surt LY
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=surt
# ------------------------
# Proceesing: City #  136  |  Port Shepstone ZA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=port+shepstone
# ------------------------
# Proceesing: City #  137  |  Quang Ngai VN
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=quang+ngai
# ------------------------
# Proceesing: City #  138  |  Axim GH
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=axim
# ------------------------
# Proceesing: City #  139  |  Solnechnyy RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=solnechnyy
# ------------------------
# Proceesing: City #  140  |  Ambovombe MG
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=ambovombe
# ------------------------
# Proceesing: City #  141  |  East Stroudsburg US
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=east+stroudsburg
# ------------------------
# Proceesing: City #  142  |  Provideniya RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=provideniya
# ------------------------
# Proceesing: City #  143  |  Altamira BR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=altamira
# ------------------------
# Proceesing: City #  144  |  Mahebourg MU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=mahebourg
# ------------------------
# Proceesing: City #  145  |  Codrington AU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=codrington
# ------------------------
# Proceesing: City #  146  |  Hualmay PE
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=hualmay
# ------------------------
# Proceesing: City #  147  |  Svirstroy RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=svirstroy
# ------------------------
# Proceesing: City #  148  |  Udachnyy RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=udachnyy
# City not found, skipping...
# ------------------------
# Proceesing: City #  149  |  Baft IR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=baft
# ------------------------
# Proceesing: City #  150  |  Kalabo ZM
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=kalabo
# ------------------------
# Proceesing: City #  151  |  Xining CN
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=xining
# City not found, skipping...
# City not found, skipping...
# City not found, skipping...
# City not found, skipping...
# ------------------------
# Proceesing: City #  152  |  Sikonge TZ
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=sikonge
# ------------------------
# Proceesing: City #  153  |  Port Hardy CA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=port+hardy
# ------------------------
# Proceesing: City #  154  |  Caravelas BR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=caravelas
# ------------------------
# Proceesing: City #  155  |  Bosaso SO
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=bosaso
# ------------------------
# Proceesing: City #  156  |  Camabatela AO
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=camabatela
# ------------------------
# Proceesing: City #  157  |  San Rafael AR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=san+rafael
# ------------------------
# Proceesing: City #  158  |  Beloha MG
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=beloha
# ------------------------
# Proceesing: City #  159  |  Alta NO
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=alta
# ------------------------
# Proceesing: City #  160  |  Taoudenni ML
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=taoudenni
# ------------------------
# Proceesing: City #  161  |  Lavrentiya RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=lavrentiya
# ------------------------
# Proceesing: City #  162  |  Tuatapere NZ
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=tuatapere
# ------------------------
# Proceesing: City #  163  |  Kokstad ZA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=kokstad
# ------------------------
# Proceesing: City #  164  |  Nome US
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=nome
# City not found, skipping...
# ------------------------
# Proceesing: City #  165  |  Georgetown GY
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=georgetown
# ------------------------
# Proceesing: City #  166  |  Hauterive FR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=hauterive
# ------------------------
# Proceesing: City #  167  |  Esperance TT
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=esperance
# ------------------------
# Proceesing: City #  168  |  Port Blair IN
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=port+blair
# ------------------------
# Proceesing: City #  169  |  Ponta do Sol BR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=ponta+do+sol
# ------------------------
# Proceesing: City #  170  |  Geraldton CA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=geraldton
# ------------------------
# Proceesing: City #  171  |  Aswan EG
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=aswan
# ------------------------
# Proceesing: City #  172  |  Zaltan LY
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=zaltan
# ------------------------
# Proceesing: City #  173  |  Ambilobe MG
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=ambilobe
# ------------------------
# Proceesing: City #  174  |  Dingle PH
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=dingle
# ------------------------
# Proceesing: City #  175  |  Am Timan TD
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=am+timan
# ------------------------
# Proceesing: City #  176  |  Emba CY
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=emba
# ------------------------
# Proceesing: City #  177  |  Mar del Plata AR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=mar+del+plata
# ------------------------
# Proceesing: City #  178  |  Auki NG
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=auki
# ------------------------
# Proceesing: City #  179  |  Constitucion MX
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=constitucion
# City not found, skipping...
# ------------------------
# Proceesing: City #  180  |  Baruun-Urt MN
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=baruun-urt
# ------------------------
# Proceesing: City #  181  |  San Quintin PH
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=san+quintin
# ------------------------
# Proceesing: City #  182  |  Mayo CA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=mayo
# ------------------------
# Proceesing: City #  183  |  Zeya RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=zeya
# City not found, skipping...
# ------------------------
# Proceesing: City #  184  |  Charters Towers AU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=charters+towers
# ------------------------
# Proceesing: City #  185  |  Smidovich RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=smidovich
# City not found, skipping...
# ------------------------
# Proceesing: City #  186  |  Cherskiy RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=cherskiy
# ------------------------
# Proceesing: City #  187  |  Wicklow IE
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=wicklow
# ------------------------
# Proceesing: City #  188  |  Ust-Maya RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=ust-maya
# ------------------------
# Proceesing: City #  189  |  Takoradi GH
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=takoradi
# ------------------------
# Proceesing: City #  190  |  Sitka US
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=sitka
# ------------------------
# Proceesing: City #  191  |  Puerto Ayora EC
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=puerto+ayora
# ------------------------
# Proceesing: City #  192  |  Miri NG
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=miri
# ------------------------
# Proceesing: City #  193  |  Gouyave GD
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=gouyave
# City not found, skipping...
# ------------------------
# Proceesing: City #  194  |  Balikpapan ID
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=balikpapan
# ------------------------
# Proceesing: City #  195  |  Baiyin CN
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=baiyin
# ------------------------
# Proceesing: City #  196  |  Bocanda CI
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=bocanda
# ------------------------
# Proceesing: City #  197  |  Casma PE
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=casma
# ------------------------
# Proceesing: City #  198  |  Oskarshamn SE
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=oskarshamn
# ------------------------
# Proceesing: City #  199  |  Kisber HU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=kisber
# ------------------------
# Proceesing: City #  200  |  Fortuna ES
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=fortuna
# ------------------------
# Proceesing: City #  201  |  Kodiak US
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=kodiak
# ------------------------
# Proceesing: City #  202  |  Inhambane MZ
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=inhambane
# ------------------------
# Proceesing: City #  203  |  Carnarvon ZA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=carnarvon
# ------------------------
# Proceesing: City #  204  |  Klaksvik FO
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=klaksvik
# ------------------------
# Proceesing: City #  205  |  San Policarpo PH
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=san+policarpo
# ------------------------
# Proceesing: City #  206  |  Mayskiy RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=mayskiy
# ------------------------
# Proceesing: City #  207  |  Coolum Beach AU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=coolum+beach
# ------------------------
# Proceesing: City #  208  |  Uyovu TZ
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=uyovu
# ------------------------
# Proceesing: City #  209  |  Tabou CI
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=tabou
# City not found, skipping...
# ------------------------
# Proceesing: City #  210  |  Viedma AR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=viedma
# ------------------------
# Proceesing: City #  211  |  Naze NG
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=naze
# ------------------------
# Proceesing: City #  212  |  Bandarbeyla SO
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=bandarbeyla
# City not found, skipping...
# ------------------------
# Proceesing: City #  213  |  Ribeira Grande PT
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=ribeira+grande
# ------------------------
# Proceesing: City #  214  |  Tilichiki RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=tilichiki
# ------------------------
# Proceesing: City #  215  |  Kurilsk RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=kurilsk
# ------------------------
# Proceesing: City #  216  |  Colares PT
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=colares
# ------------------------
# Proceesing: City #  217  |  Cordoba CO
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=cordoba
# ------------------------
# Proceesing: City #  218  |  Nara JP
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=nara
# City not found, skipping...
# ------------------------
# Proceesing: City #  219  |  Kedrovyy RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=kedrovyy
# ------------------------
# Proceesing: City #  220  |  Moerai PF
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=moerai
# City not found, skipping...
# ------------------------
# Proceesing: City #  221  |  Jacareacanga BR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=jacareacanga
# ------------------------
# Proceesing: City #  222  |  Walvis Bay NA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=walvis+bay
# City not found, skipping...
# City not found, skipping...
# ------------------------
# Proceesing: City #  223  |  Sayat TM
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=sayat
# City not found, skipping...
# ------------------------
# Proceesing: City #  224  |  Varhaug NO
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=varhaug
# ------------------------
# Proceesing: City #  225  |  Pisco PE
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=pisco
# ------------------------
# Proceesing: City #  226  |  Tessalit ML
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=tessalit
# ------------------------
# Proceesing: City #  227  |  Talnakh RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=talnakh
# ------------------------
# Proceesing: City #  228  |  Vardo US
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=vardo
# ------------------------
# Proceesing: City #  229  |  Norman Wells CA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=norman+wells
# ------------------------
# Proceesing: City #  230  |  Kahului US
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=kahului
# ------------------------
# Proceesing: City #  231  |  Bobcaygeon CA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=bobcaygeon
# ------------------------
# Proceesing: City #  232  |  Illapel CL
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=illapel
# ------------------------
# Proceesing: City #  233  |  Nikolskoye RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=nikolskoye
# ------------------------
# Proceesing: City #  234  |  Sarangani PH
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=sarangani
# ------------------------
# Proceesing: City #  235  |  Tambo AU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=tambo
# ------------------------
# Proceesing: City #  236  |  Salinopolis BR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=salinopolis
# ------------------------
# Proceesing: City #  237  |  Kaitangata NZ
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=kaitangata
# ------------------------
# Proceesing: City #  238  |  San Carlos VE
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=san+carlos
# ------------------------
# Proceesing: City #  239  |  Sungaipenuh ID
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=sungaipenuh
# ------------------------
# Proceesing: City #  240  |  Zhiryatino RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=zhiryatino
# ------------------------
# Proceesing: City #  241  |  Ntungamo UG
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=ntungamo
# ------------------------
# Proceesing: City #  242  |  Kazerun IR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=kazerun
# City not found, skipping...
# ------------------------
# Proceesing: City #  243  |  Denton US
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=denton
# ------------------------
# Proceesing: City #  244  |  Saldanha PT
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=saldanha
# ------------------------
# Proceesing: City #  245  |  Washougal US
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=washougal
# ------------------------
# Proceesing: City #  246  |  Ajdabiya LY
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=ajdabiya
# City not found, skipping...
# ------------------------
# Proceesing: City #  247  |  Erattupetta IN
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=erattupetta
# ------------------------
# Proceesing: City #  248  |  Rawson AR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=rawson
# ------------------------
# Proceesing: City #  249  |  Sept-Iles CA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=sept-iles
# City not found, skipping...
# ------------------------
# Proceesing: City #  250  |  Maniitsoq GL
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=maniitsoq
# ------------------------
# Proceesing: City #  251  |  Gwadar PK
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=gwadar
# ------------------------
# Proceesing: City #  252  |  Steamboat Springs US
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=steamboat+springs
# City not found, skipping...
# ------------------------
# Proceesing: City #  253  |  Hami CN
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=hami
# City not found, skipping...
# ------------------------
# Proceesing: City #  254  |  Sainte-Marie CA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=sainte-marie
# ------------------------
# Proceesing: City #  255  |  Sri Aman MY
# ...
# ------------------------
# Proceesing: City #  513  |  Chandvad IN
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=chandvad
# City not found, skipping...
# ------------------------
# Proceesing: City #  514  |  Pulandian CN
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=pulandian
# ------------------------
# Proceesing: City #  515  |  Evans US
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=evans
# ------------------------
# Proceesing: City #  516  |  Sobolevo RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=sobolevo
# ------------------------
# Proceesing: City #  517  |  Adrar DZ
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=adrar
# ------------------------
# Proceesing: City #  518  |  Kiunga PG
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=kiunga
# ------------------------
# Proceesing: City #  519  |  Tautira PF
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=tautira
# ------------------------
# Proceesing: City #  520  |  Batemans Bay AU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=batemans+bay
# ------------------------
# Proceesing: City #  521  |  Abonnema NG
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=abonnema
# ------------------------
# Proceesing: City #  522  |  Greenwood US
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=greenwood
# City not found, skipping...
# ------------------------
# Proceesing: City #  523  |  Flinders AU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=flinders
# ------------------------
# Proceesing: City #  524  |  Shahpur IN
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=shahpur
# ------------------------
# Proceesing: City #  525  |  Okitipupa NG
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=okitipupa
# ------------------------
# Proceesing: City #  526  |  Martapura ID
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=martapura
# ------------------------
# Proceesing: City #  527  |  Les Cayes HT
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=les+cayes
# City not found, skipping...
# ------------------------
# Proceesing: City #  528  |  Bogorodskoye RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=bogorodskoye
# City not found, skipping...
# ------------------------
# Proceesing: City #  529  |  Waingapu ID
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=waingapu
# ------------------------
# Proceesing: City #  530  |  Killybegs IE
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=killybegs
# ------------------------
# Proceesing: City #  531  |  Vestmannaeyjar IS
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=vestmannaeyjar
# ------------------------
# Proceesing: City #  532  |  Channel-Port aux Basques CA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=channel-port+aux+basques
# ------------------------
# Proceesing: City #  533  |  Marsh Harbour BS
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=marsh+harbour
# ------------------------
# Proceesing: City #  534  |  Sangar RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=sangar
# ------------------------
# Proceesing: City #  535  |  Termoli IT
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=termoli
# ------------------------
# Proceesing: City #  536  |  Alpena US
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=alpena
# ------------------------
# Proceesing: City #  537  |  Aksu KZ
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=aksu
# ------------------------
# Proceesing: City #  538  |  Musafirkhana IN
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=musafirkhana
# ------------------------
# Proceesing: City #  539  |  Ukiah US
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=ukiah
# ------------------------
# Proceesing: City #  540  |  Luba PH
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=luba
# ------------------------
# Proceesing: City #  541  |  Turbat PK
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=turbat
# ------------------------
# Proceesing: City #  542  |  Lichtenburg ZA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=lichtenburg
# ------------------------
# Proceesing: City #  543  |  Klichka RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=klichka
# ------------------------
# Proceesing: City #  544  |  Mecca SA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=mecca
# ------------------------
# Proceesing: City #  545  |  Kovur IN
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=kovur
# ------------------------
# Proceesing: City #  546  |  Prado BR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=prado
# ------------------------
# Proceesing: City #  547  |  Amapa HN
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=amapa
# City not found, skipping...
# ------------------------
# Proceesing: City #  548  |  Portree GB
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=portree
# ------------------------
# Proceesing: City #  549  |  Paris FR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=paris
# ------------------------
# Proceesing: City #  550  |  Manado ID
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=manado
# ------------------------
# Proceesing: City #  551  |  Ziro IN
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=ziro
# ------------------------
# Proceesing: City #  552  |  Mutoko ZW
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=mutoko
# ------------------------
# Proceesing: City #  553  |  Talara PE
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=talara
# ------------------------
# Proceesing: City #  554  |  Requena ES
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=requena
# ------------------------
# Proceesing: City #  555  |  Road Town VG
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=road+town
# ------------------------
# Proceesing: City #  556  |  Millinocket US
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=millinocket
# ------------------------
# Proceesing: City #  557  |  Cedral MX
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=cedral
# ------------------------
# Proceesing: City #  558  |  Hemsedal NO
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=hemsedal
# City not found, skipping...
# ------------------------
# Proceesing: City #  559  |  Moche PE
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=moche
# ------------------------
# Proceesing: City #  560  |  Seybaplaya MX
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=seybaplaya
# ------------------------
# Proceesing: City #  561  |  Nyurba RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=nyurba
# City not found, skipping...
# ------------------------
# Proceesing: City #  562  |  Talcahuano CL
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=talcahuano
# ------------------------
# Proceesing: City #  563  |  Christchurch NZ
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=christchurch
# ------------------------
# Proceesing: City #  564  |  Marmande FR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=marmande
# ------------------------
# Proceesing: City #  565  |  Zhangjiakou CN
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=zhangjiakou
# ------------------------
# Proceesing: City #  566  |  Hovd NO
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=hovd
# City not found, skipping...
# City not found, skipping...
# ------------------------
# Proceesing: City #  567  |  Muros ES
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=muros
# ------------------------
# Proceesing: City #  568  |  Sao Gabriel da Cachoeira BR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=sao+gabriel+da+cachoeira
# City not found, skipping...
# ------------------------
# Proceesing: City #  569  |  Chunoyar RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=chunoyar
# ------------------------
# Proceesing: City #  570  |  Myitkyina MM
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=myitkyina
# City not found, skipping...
# ------------------------
# Proceesing: City #  571  |  Pullman US
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=pullman
# ------------------------
# Proceesing: City #  572  |  Krasnokamensk RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=krasnokamensk
# ------------------------
# Proceesing: City #  573  |  Pakaur IN
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=pakaur
# ------------------------
# Proceesing: City #  574  |  Sabang PH
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=sabang
# ------------------------
# Proceesing: City #  575  |  Rybinsk RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=rybinsk
# ------------------------
# Proceesing: City #  576  |  Kiruna SE
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=kiruna
# ------------------------
# Proceesing: City #  577  |  Telenesti MD
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=telenesti
# ------------------------
# Proceesing: City #  578  |  El Sauzal AR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=el+sauzal
# ------------------------
# Proceesing: City #  579  |  Molteno ZA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=molteno
# ------------------------
# Proceesing: City #  580  |  Karabash RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=karabash
# ------------------------
# Proceesing: City #  581  |  Goderich CA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=goderich
# ------------------------
# Proceesing: City #  582  |  Sorland NO
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=sorland
# ------------------------
# Proceesing: City #  583  |  Aykhal RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=aykhal
# ------------------------
# Proceesing: City #  584  |  Alexandria US
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=alexandria
# ------------------------
# Proceesing: City #  585  |  Caconda AO
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=caconda
# ------------------------
# Proceesing: City #  586  |  Quatre Cocos MU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=quatre+cocos
# ------------------------
# Proceesing: City #  587  |  Votkinsk RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=votkinsk
# ------------------------
# Proceesing: City #  588  |  Hobyo SO
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=hobyo
# ------------------------
# Proceesing: City #  589  |  Los Arabos CU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=los+arabos
# ------------------------
# Proceesing: City #  590  |  Guaruja BR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=guaruja
# ------------------------
# Proceesing: City #  591  |  Ca Mau VN
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=ca+mau
# ------------------------
# Proceesing: City #  592  |  Yurimaguas PE
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=yurimaguas
# ------------------------
# Proceesing: City #  593  |  Makarov RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=makarov
# ------------------------
# Proceesing: City #  594  |  Zhanakorgan KZ
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=zhanakorgan
# ------------------------
# Proceesing: City #  595  |  Boromlya UA
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=boromlya
# ------------------------
# Proceesing: City #  596  |  Upata VE
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=upata
# ------------------------
# Proceesing: City #  597  |  Saint-Pierre FR
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=saint-pierre
# ------------------------
# Proceesing: City #  598  |  Polyarnyy RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=polyarnyy
# ------------------------
# Proceesing: City #  599  |  Zelenoborsk RU
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=zelenoborsk
# ------------------------
# Proceesing: City #  600  |  Gombong ID
# http://api.openweathermap.org/data/2.5/weather?appid=d6810bdaefe467cd40907ae8b7ed7c10&units=IMPERIAL&q=gombong

# %% [markdown]
# ## Perform API Calls

# %%
clean_cities_df.count()
# Out:
# City                600
# Country             600
# Temperature (F)     600
# Latitude            600
# Longitude           600
# Humidity (%)        600
# Cloudiness (%)      600
# Wind Speed (mph)    600
# dtype: int64

# %%
clean_cities_df = clean_cities_df.reset_index()
del clean_cities_df['index']
clean_cities_df.head(25)
# Out:
#                City Country Temperature (F) Latitude Longitude Humidity (%)  \
# 0             Kapaa      US            82.2    22.08   -159.32           74
# 1         Sistranda      NO            44.6    63.73      8.83          100
# 2       New Norfolk      AU            53.6   -42.78    147.06           71
# 3           Katwijk      NL           53.87     52.2      4.41          100
# 4     Makakilo City      US           80.42    21.35   -158.09           54
# 5            Castro      CL           28.11   -42.48    -73.76          100
# 6       Port Alfred      ZA           65.01   -33.59     26.89           90
# 7      Saint George      GR              68    39.45     22.34           68
# 8     Victor Harbor      AU            57.2   -35.55    138.62           76
# 9            Matara      PE           27.57   -13.74     -72.9           82
# 10           Albany      US           62.24    42.65    -73.75           64
# 11   Port Elizabeth      US           77.81    39.31    -74.98           87
# 12           Hobart      AU            53.6   -42.88    147.33           66
# 13  Haines Junction      CA           40.62    60.75   -137.51           91
# 14      Green River      US           66.02    41.53   -109.47            5
# 15          Iqaluit      CA            37.4    63.75    -68.52           99
# 16            Seoul      KR           80.94    37.57    126.98           57
# 17        La Orilla      MX            77.7       18   -102.23          100
# 18    Cockburn Town      TC           81.66    21.46    -71.14          100
# 19          Rikitea      PF           70.14   -23.12   -134.97          100
# 20   Severo-Kurilsk      RU           52.41    50.68    156.12           93
# 21         Victoria      BN           88.72     5.28    115.24           70
# 22            Bluff      AU           84.54   -23.58    149.07           26
# 23         Pacifica      US           62.64    37.61   -122.49           77
# 24           Bethel      US           51.08    60.79   -161.76           92
#
#    Cloudiness (%) Wind Speed (mph)
# 0              40            18.34
# 1              40             6.93
# 2              75              4.7
# 3              80             6.29
# 4               1             9.17
# 5               0             3.38
# 6              56             9.31
# 7              20             6.93
# 8              20            11.41
# 9               0             1.92
# 10             75             6.93
# 11              1             4.61
# 12             75             6.93
# 13             80              3.6
# 14              1             9.17
# 15             75             3.36
# 16             20             9.17
# 17             76             2.04
# 18             76            20.27
# 19              8            21.39
# 20             48             8.52
# 21             75             2.24
# 22              0            12.33
# 23             75            23.04
# 24             90            14.99

# %%
plt.scatter(clean_cities_df["Latitude"], 
            clean_cities_df["Temperature (F)"], c=clean_cities_df["Temperature (F)"],
            edgecolor="black", linewidths=1, marker="o", 
            cmap='Blues', alpha=0.8, label="City")

# Incorporate the other graph properties
plt.style.use('seaborn')
plt.title(f"City Latitude vs. Max Temperature {datetime.now().strftime('%m/%d/%Y')}")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-80, 100])
plt.ylim([-60, 120])

# Save the figure
plt.savefig("Latitude_Temperature.png")

# Show plot
plt.show()

# %%
#Build a scatter plot for Latitude vs. Humidity (%)

plt.scatter(clean_cities_df["Latitude"], 
            clean_cities_df["Humidity (%)"], c=clean_cities_df["Humidity (%)"],
            edgecolor="black", linewidths=1, marker="o", 
            cmap='Greens_r', alpha=0.8, label="City")

# Incorporate the other graph properties
plt.style.use('seaborn')
plt.title(f"City Latitude vs. Humidity (%) {datetime.now().strftime('%m/%d/%Y')}")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-80, 100])
plt.ylim([-5, 125])

# Save the figure
plt.savefig("Latitude_Humidity.png")

# Show plot
plt.show()

# %%
plt.scatter(clean_cities_df["Latitude"], 
            clean_cities_df["Cloudiness (%)"], c=clean_cities_df["Cloudiness (%)"],
            edgecolor="reds", linewidths=1, marker="x", 
            cmap='bone_r', alpha=0.8, label="City")

# Incorporate the other graph properties
plt.style.use('seaborn')
plt.title(f"City Latitude vs. Cloudiness (%) {datetime.now().strftime('%m/%d/%Y')}")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-80, 100])
plt.ylim([-10, 125])

# Save the figure
plt.savefig("Latitude_Cloudiness.png")

# Show plot
plt.show()

# %%
#Build a scatter plot for Latitude vs. Wind Speed (mph)

plt.scatter(clean_cities_df["Latitude"], 
            clean_cities_df["Wind Speed (mph)"], c=clean_cities_df["Wind Speed (mph)"],
            edgecolor="ocean", linewidths=1, marker="x", 
            cmap='Spectral_r', alpha=0.8, label="City")

# Incorporate the other graph properties
plt.style.use('seaborn')
plt.title(f"City Latitude vs. Wind Speed (mph) {datetime.now().strftime('%m/%d/%Y')}")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-80, 100])
plt.ylim([-10, 50])

# Save the figure
plt.savefig("Latitude_WindSpeed.png")

# Show plot
plt.show()

# %%
#Build a scatter plot for Latitude vs. Wind Speed (mph)

plt.scatter(clean_cities_df["Longitude"], 
            clean_cities_df["Latitude"], c=clean_cities_df["Latitude"],
            edgecolor="black", linewidths=1, marker="o", 
            cmap='ocean', alpha=0.8, label="City")

# Incorporate the other graph properties
plt.style.use('seaborn')
plt.title(f"Longitude vs. Latitude {datetime.now().strftime('%m/%d/%Y')}")
plt.ylabel("Latitude")
plt.xlabel("Longitude")
plt.grid(True)
plt.xlim([-200, 200])
plt.ylim([-80, 100])

# Save the figure
plt.savefig("Latitude_Longitude.png")

# Show plot
plt.show()
